# %%
#installing dependencies
import pandas as pd
import seaborn as sns
import numpy as np

# %%
data = pd.read_excel("D:/Folder for Notes/Project Section/Total All Datasets for Predictive Maintenance/Final Dataset head.xlsx")

# %%
data.head()
# Out:
#    Unnamed: 0  id  cycle  setting 1  setting 2        s2        s3        s4  \
# 0           0   1      1    0.65625   0.692308  0.596215  0.421968  0.282214
# 1           1   1      2    0.34375   0.230769  0.182965  0.504025  0.225240
# 2           2   1      3    0.53125   0.538462  0.419558  0.464814  0.346130
# 3           3   1      4    0.77500   0.461538  0.413249  0.391587  0.449867
# 4           4   1      5    0.60000   0.461538  0.435331  0.471306  0.357974
#
#    s6        s7  ...       s12       s13       s14       s15    s17       s20  \
# 0   1  0.608871  ...  0.534247  0.325581  0.152259  0.347076  0.375  0.500000
# 1   1  0.800403  ...  0.634703  0.395349  0.277907  0.227709  0.500  0.645455
# 2   1  0.651210  ...  0.591324  0.325581  0.192892  0.533557  0.500  0.700000
# 3   1  0.641345  ...  0.456621  0.372093  0.217896  0.282359  0.250  0.627273
# 4   1  0.661290  ...  0.632420  0.325581  0.187891  0.337009  0.125  0.618182
#
# ...

# %%
data.tail()
# Out:
#    Unnamed: 0  id  cycle  setting 1  setting 2        s2        s3        s4  \
# 0           0   1      1    0.65625   0.692308  0.596215  0.421968  0.282214
# 1           1   1      2    0.34375   0.230769  0.182965  0.504025  0.225240
# 2           2   1      3    0.53125   0.538462  0.419558  0.464814  0.346130
# 3           3   1      4    0.77500   0.461538  0.413249  0.391587  0.449867
# 4           4   1      5    0.60000   0.461538  0.435331  0.471306  0.357974
#
#    s6        s7  ...       s12       s13       s14       s15    s17       s20  \
# 0   1  0.608871  ...  0.534247  0.325581  0.152259  0.347076  0.375  0.500000
# 1   1  0.800403  ...  0.634703  0.395349  0.277907  0.227709  0.500  0.645455
# 2   1  0.651210  ...  0.591324  0.325581  0.192892  0.533557  0.500  0.700000
# 3   1  0.641345  ...  0.456621  0.372093  0.217896  0.282359  0.250  0.627273
# 4   1  0.661290  ...  0.632420  0.325581  0.187891  0.337009  0.125  0.618182
#
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'id', 'cycle', 'setting 1', 'setting 2', 's2', 's3', 's4',
#        's6', 's7', 's8', 's9', 's11', 's12', 's13', 's14', 's15', 's17', 's20',
#        's21', 'RUL', 'label 1', 'label 2'],
#       dtype='object')

# %%
data.shape
# Out:
# (5, 23)

# %%
data.describe()
# Out:
#        Unnamed: 0   id     cycle  setting 1  setting 2        s2        s3  \
# count    5.000000  5.0  5.000000   5.000000   5.000000  5.000000  5.000000
# mean     2.000000  1.0  3.000000   0.581250   0.476923  0.409464  0.450740
# std      1.581139  0.0  1.581139   0.160017   0.166766  0.147447  0.044123
# min      0.000000  1.0  1.000000   0.343750   0.230769  0.182965  0.391587
# 25%      1.000000  1.0  2.000000   0.531250   0.461538  0.413249  0.421968
# 50%      2.000000  1.0  3.000000   0.600000   0.461538  0.419558  0.464814
# 75%      3.000000  1.0  4.000000   0.656250   0.538462  0.435331  0.471306
# max      4.000000  1.0  5.000000   0.775000   0.692308  0.596215  0.504025
#
#              s4   s6        s7  ...       s12       s13       s14       s15  \
# count  5.000000  5.0  5.000000  ...  5.000000  5.000000  5.000000  5.000000
# mean   0.332285  1.0  0.672624  ...  0.569863  0.348837  0.205769  0.345542
# ...

# %%
#visualization
data.isnull().sum()
# Out:
# Unnamed: 0    0
# id            0
# cycle         0
# setting 1     0
# setting 2     0
# s2            0
# s3            0
# s4            0
# s6            0
# s7            0
# s8            0
# s9            0
# s11           0
# s12           0
# s13           0
# s14           0
# s15           0
# s17           0
# s20           0
# s21           0
# RUL           0
# label 1       0
# label 2       0
# dtype: int64

# %%
#visualization
data.head()
# Out:
#    Unnamed: 0  id  cycle  setting 1  setting 2        s2        s3        s4  \
# 0           0   1      1    0.65625   0.692308  0.596215  0.421968  0.282214
# 1           1   1      2    0.34375   0.230769  0.182965  0.504025  0.225240
# 2           2   1      3    0.53125   0.538462  0.419558  0.464814  0.346130
# 3           3   1      4    0.77500   0.461538  0.413249  0.391587  0.449867
# 4           4   1      5    0.60000   0.461538  0.435331  0.471306  0.357974
#
#    s6        s7  ...       s12       s13       s14       s15    s17       s20  \
# 0   1  0.608871  ...  0.534247  0.325581  0.152259  0.347076  0.375  0.500000
# 1   1  0.800403  ...  0.634703  0.395349  0.277907  0.227709  0.500  0.645455
# 2   1  0.651210  ...  0.591324  0.325581  0.192892  0.533557  0.500  0.700000
# 3   1  0.641345  ...  0.456621  0.372093  0.217896  0.282359  0.250  0.627273
# 4   1  0.661290  ...  0.632420  0.325581  0.187891  0.337009  0.125  0.618182
#
# ...

# %%
sns.relplot(x = 'cycle', y = 'setting 1', data = data)

# %%
sns.relplot(x = 'cycle', y = 'setting 2', hue = 's2', data = data)

# %%
#model
data.head()
# Out:
#    Unnamed: 0  id  cycle  setting 1  setting 2        s2        s3        s4  \
# 0           0   1      1    0.65625   0.692308  0.596215  0.421968  0.282214
# 1           1   1      2    0.34375   0.230769  0.182965  0.504025  0.225240
# 2           2   1      3    0.53125   0.538462  0.419558  0.464814  0.346130
# 3           3   1      4    0.77500   0.461538  0.413249  0.391587  0.449867
# 4           4   1      5    0.60000   0.461538  0.435331  0.471306  0.357974
#
#    s6        s7  ...       s12       s13       s14       s15    s17       s20  \
# 0   1  0.608871  ...  0.534247  0.325581  0.152259  0.347076  0.375  0.500000
# 1   1  0.800403  ...  0.634703  0.395349  0.277907  0.227709  0.500  0.645455
# 2   1  0.651210  ...  0.591324  0.325581  0.192892  0.533557  0.500  0.700000
# 3   1  0.641345  ...  0.456621  0.372093  0.217896  0.282359  0.250  0.627273
# 4   1  0.661290  ...  0.632420  0.325581  0.187891  0.337009  0.125  0.618182
#
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
train = data.drop(['cycle', 'setting 1', 'id'], axis=1)
test = data['cycle']

# %%
x_train, x_test, y_train, y_test = train_test_split(train, test, test_size = 0.3, random_state = 2)

# %%
regr = LinearRegression()

# %%
regr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pred = regr.predict(x_test)

# %%
pred
# Out:
# array([2.98129009, 4.97906334])

# %%
regr.score(x_test, y_test)
# Out:
# 0.9996057977377797
